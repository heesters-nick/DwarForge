# %%
# Imports
import pandas as pd
import os
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
import xgboost as xgb
from sklearn.metrics import (
    ConfusionMatrixDisplay,
    accuracy_score,
    average_precision_score,
    confusion_matrix,
    f1_score,
    precision_recall_curve,
    precision_score,
    recall_score,
    roc_auc_score,
    make_scorer,
)
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.calibration import calibration_curve
from scipy.stats import uniform, randint

# %% [markdown]
# # Paths

# %%
tables = "/arc/home/heestersnick/dwarforge/tables"
models = "/arc/home/heestersnick/dwarforge/models"
data_dir = "/arc/projects/unions/ssl/data/raw/tiles/dwarforge"
training_data_file = "umap_data_master.parquet"
if training_data_file.endswith(".csv"):
    training_data = pd.read_csv(os.path.join(tables, training_data_file))
elif training_data_file.endswith(".parquet"):
    training_data = pd.read_parquet(os.path.join(tables, training_data_file))
    training_data["lsb_cfis_lsb-r"] = training_data["lsb_cfis_lsb-r"].fillna(0)
    training_data.rename(columns={"lsb_cfis_lsb-r": "lsb"}, inplace=True)
    training_data.drop(columns=["lsb_whigs-g"], inplace=True)
    training_data.drop(columns=["lsb_ps-i"], inplace=True)

# %% [markdown]
# # Functions

# %%
def plot_confusion_matrix(
    y_true, y_pred, labels, title="Confusion Matrix", cmap="viridis"
):
    cm = confusion_matrix(y_true, y_pred)
    cm_percentage = cm.astype("float") / cm.sum(axis=1)[:, np.newaxis] * 100
    # cm_norm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    gs = plt.GridSpec(
        len(labels), len(labels) + 1, width_ratios=[4] * len(labels) + [0.1]
    )
    plt.figure(figsize=(len(labels) + 3, len(labels) + 3))
    ax = sns.heatmap(
        cm,
        annot=False,
        cmap=cmap,
        cbar_kws={"shrink": 0.805},
        square=True,
        xticklabels=labels,
        yticklabels=labels,
    )

    for i in range(len(labels)):
        for j in range(len(labels)):
            if i == j:
                ax.text(
                    j + 0.5,
                    i + 0.5,
                    f"{cm[i, j]:d}\n{cm_percentage[i, j]:.1f}%",
                    ha="center",
                    va="center",
                    fontsize=10,
                    color="black",
                )
            else:
                ax.text(
                    j + 0.5,
                    i + 0.5,
                    f"{cm[i, j]:d}\n{cm_percentage[i, j]:.1f}%",
                    ha="center",
                    va="center",
                    fontsize=10,
                    color="white",
                )

    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title(title)
    # plt.savefig('/home/nick/Documents/Candidacy_Exam/Presentation/Figures/'+'cm_w_percentage.png', bbox_inches='tight', dpi=300)
    plt.show()


def classify_and_save_parquet(
    parent_folder, random_forest_model, features, df_path_out, band="cfis_lsb-r"
):
    pattern = os.path.join(
        parent_folder, "*_*", band, "CFIS_LSB.*.r_rebin_det_params.parquet"
    )
    positive_class_rows = []
    for file in tqdm(glob(pattern)):
        try:
            filename = os.path.basename(file)
            tile_numbers = filename.split(".")[1:3]
            tile_id = f"({tile_numbers[0]}, {tile_numbers[1]})"

            # Read the parquet file
            df = pd.read_parquet(file)

            # Select only the columns used for inference
            X = df[features]

            # Apply the random forest model
            df["class"] = random_forest_model.predict(X)

            # Aggregate rows where class = 1
            positive_rows = df[df["class"] == 1].copy()
            positive_rows["tile"] = tile_id  # Add file path for reference
            positive_class_rows.append(positive_rows)

            # Save the updated dataframe back to parquet
            df.to_parquet(file, index=False)

        except Exception as e:
            print(f"Error processing file {file}: {str(e)}")
            continue

    # Combine all positive class rows into a single DataFrame
    if positive_class_rows:
        all_positive_rows = pd.concat(positive_class_rows, ignore_index=True)
        all_positive_rows.to_parquet(df_path_out, index=False)
    else:
        all_positive_rows = pd.DataFrame()

    return all_positive_rows


def evaluate_model(model, X_test, y_test):
    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    # Basic metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Additional metrics
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    balanced_accuracy = (recall + specificity) / 2

    # ROC AUC
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    # Average Precision (AP) summarizes a precision-recall curve
    average_precision = average_precision_score(y_test, y_pred_proba)

    # Print metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy:.4f}")
    print(f"ROC AUC: {roc_auc:.4f}")
    print(f"Average Precision: {average_precision:.4f}")

    plot_confusion_matrix(y_test, y_pred, labels=["no dwarf", "dwarf"])

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    plt.figure(figsize=(8, 6))
    plt.step(recall, precision, color="b", alpha=0.2, where="post")
    plt.fill_between(recall, precision, step="post", alpha=0.2, color="b")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(f"Precision-Recall curve: AP={average_precision:0.2f}")
    plt.show()

    # Calibration curve
    prob_true, prob_pred = calibration_curve(y_test, y_pred_proba, n_bins=10)
    plt.figure(figsize=(8, 6))
    plt.plot(prob_pred, prob_true, marker="o")
    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("Mean predicted probability")
    plt.ylabel("Fraction of positives")
    plt.title("Calibration Curve")
    plt.show()


def sample_and_shuffle_data(df, label_column="lsb", neg_pos_ratio=3, random_state=42):
    # Separate positive and negative examples
    positive_df = df[df[label_column] == 1]
    negative_df = df[df[label_column] == 0]

    # Calculate the number of negative examples to keep
    n_positive = len(positive_df)
    n_negative_to_keep = n_positive * neg_pos_ratio

    # Sample negative examples
    if len(negative_df) > n_negative_to_keep:
        negative_sample = negative_df.sample(
            n=int(n_negative_to_keep), random_state=random_state
        )
    else:
        negative_sample = negative_df  # Keep all if we don't have enough

    # Combine positive examples with sampled negative examples
    combined_df = pd.concat([positive_df, negative_sample])

    # Shuffle the combined DataFrame
    shuffled_df = combined_df.sample(frac=1, random_state=random_state).reset_index(
        drop=True
    )

    return shuffled_df

def evaluate_model(model, X_test, y_test):
    # Predictions
    y_pred = model.predict(X_test)
    y_pred_proba = model.predict_proba(X_test)[:, 1]

    # Basic metrics
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    # Additional metrics
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    specificity = tn / (tn + fp)
    balanced_accuracy = (recall + specificity) / 2

    # ROC AUC
    roc_auc = roc_auc_score(y_test, y_pred_proba)

    # Average Precision (AP) summarizes a precision-recall curve
    average_precision = average_precision_score(y_test, y_pred_proba)

    # Print metrics
    print(f"Accuracy: {accuracy:.4f}")
    print(f"Precision: {precision:.4f}")
    print(f"Recall (Sensitivity): {recall:.4f}")
    print(f"Specificity: {specificity:.4f}")
    print(f"F1 Score: {f1:.4f}")
    print(f"Balanced Accuracy: {balanced_accuracy:.4f}")
    print(f"ROC AUC: {roc_auc:.4f}")
    print(f"Average Precision: {average_precision:.4f}")

    plot_confusion_matrix(y_test, y_pred, labels=["no dwarf", "dwarf"])

    # Precision-Recall Curve
    precision, recall, _ = precision_recall_curve(y_test, y_pred_proba)
    plt.figure(figsize=(8, 6))
    plt.step(recall, precision, color="b", alpha=0.2, where="post")
    plt.fill_between(recall, precision, step="post", alpha=0.2, color="b")
    plt.xlabel("Recall")
    plt.ylabel("Precision")
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title(f"Precision-Recall curve: AP={average_precision:0.2f}")
    plt.show()

    # Calibration curve
    prob_true, prob_pred = calibration_curve(y_test, y_pred_proba, n_bins=10)
    plt.figure(figsize=(8, 6))
    plt.plot(prob_pred, prob_true, marker="o")
    plt.plot([0, 1], [0, 1], linestyle="--")
    plt.xlabel("Mean predicted probability")
    plt.ylabel("Fraction of positives")
    plt.title("Calibration Curve")
    plt.show()

# %% [markdown]
# # Data loading

# %%
# features = ['total_flux', 'mu_max', 'mu_median', 'mu_mean', 'n_pix', 're_arcsec', 'r_fwhm_arcsec', 'r_10_arcsec', 'r_25_arcsec', 'r_75_arcsec', 'r_90_arcsec', 'r_100_arcsec', 'A_arcsec', 'B_arcsec', 'axis_ratio', 'mag', 'mu', 'lsb']
features = [
    #"total_flux_cfis_lsb-r",
    #"mu_max_cfis_lsb-r",
    #"mu_median_cfis_lsb-r",
    #"mu_mean_cfis_lsb-r",
    "re_arcsec_cfis_lsb-r",
    #"r_fwhm_arcsec_cfis_lsb-r",
    "r_10_arcsec_cfis_lsb-r",
    "r_25_arcsec_cfis_lsb-r",
    "r_75_arcsec_cfis_lsb-r",
    "r_90_arcsec_cfis_lsb-r",
    #"r_100_arcsec_cfis_lsb-r",
    "axis_ratio_cfis_lsb-r",
    "mag_cfis_lsb-r",
    "mu_cfis_lsb-r",
    #"total_flux_whigs-g",
    # "mu_max_whigs-g",
    # "mu_median_whigs-g",
    # "mu_mean_whigs-g",
    "re_arcsec_whigs-g",
    # "r_fwhm_arcsec_whigs-g",
    "r_10_arcsec_whigs-g",
    "r_25_arcsec_whigs-g",
    "r_75_arcsec_whigs-g",
    "r_90_arcsec_whigs-g",
    # "r_100_arcsec_whigs-g",
    # "axis_ratio_whigs-g",
    "mag_whigs-g",
    "mu_whigs-g",
    # "total_flux_ps-i",
    # "mu_max_ps-i",
    # "mu_median_ps-i",
    # "mu_mean_ps-i",
    "re_arcsec_ps-i",
    # "r_fwhm_arcsec_ps-i",
    "r_10_arcsec_ps-i",
    "r_25_arcsec_ps-i",
    "r_75_arcsec_ps-i",
    "r_90_arcsec_ps-i",
    # "r_100_arcsec_ps-i",
    # "axis_ratio_ps-i",
    "mag_ps-i",
    "mu_ps-i",
    "lsb",
]
dwarf_column = "lsb"
training_df = training_data[features]
training_df = sample_and_shuffle_data(training_df, neg_pos_ratio=3.0)
X, y = training_df.drop(columns=[dwarf_column]), training_df[dwarf_column]
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=np.random.randint(99)
)
print(
    f"Using {len(training_df)} examples. {np.count_nonzero(y == 1)} positive and {np.count_nonzero(y==0)} negative ones."
)
print(f"{len(X_train)} are used for training, {len(X_test)} for testing.")
# Out:
# Using 4184 examples. 1046 positive and 3138 negative ones.
# 3347 are used for training, 837 for testing.

# %% [markdown]
# # XGBoost

# %%
# Create DMatrix objects
dtrain = xgb.DMatrix(X_train, label=y_train)
dtest = xgb.DMatrix(X_test, label=y_test)

# Create an XGBoost classifier
xgb_model = xgb.XGBClassifier(use_label_encoder=False, eval_metric='auc')

# # Define the parameter grid
# param_grid = {
#     'max_depth': [3, 5, 7],
#     'learning_rate': [0.01, 0.1],
#     'n_estimators': [100, 200],
#     'min_child_weight': [1, 5],
#     'gamma': [0, 0.1],
#     'subsample': [0.8, 1.0],
#     'colsample_bytree': [0.8, 1.0]
# }


# # Set up RandomizedSearchCV
# random_search = RandomizedSearchCV(
#     estimator=xgb_model,
#     param_distributions=param_grid,
#     n_iter=20,  # number of parameter settings that are sampled
#     scoring=make_scorer(accuracy_score),
#     cv=3,  # reduced from 5 to 3
#     verbose=2,
#     n_jobs=-1,
#     random_state=42
# )

scale_pos_weight = 2.0

param_grid = {
    'max_depth': randint(3, 10),
    'learning_rate': uniform(0.01, 0.3),
    'n_estimators': randint(100, 1000),
    'min_child_weight': randint(1, 10),
    'gamma': uniform(0, 0.5),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'scale_pos_weight': [scale_pos_weight, 1]  # Try both weighted and unweighted
}

# Set up RandomizedSearchCV
random_search = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_grid,
    n_iter=50,  # number of parameter settings that are sampled
    scoring=make_scorer(roc_auc_score),
    cv=5,
    verbose=2,
    n_jobs=-1,
    random_state=42
)

# %%
# Fit the grid search to the data
random_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END colsample_bytree=0.749816047538945, gamma=0.4753571532049581, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=5, n_estimators=714, scale_pos_weight=1, subsample=0.662397808134481; total time=   1.0s
# [CV] END colsample_bytree=0.749816047538945, gamma=0.4753571532049581, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=5, n_estimators=714, scale_pos_weight=1, subsample=0.662397808134481; total time=   1.0s
# [CV] END colsample_bytree=0.6232334448672797, gamma=0.4330880728874676, learning_rate=0.19033450352296263, max_depth=5, min_child_weight=6, n_estimators=408, scale_pos_weight=1, subsample=0.8887995089067299; total time=   0.5s
# [CV] END colsample_bytree=0.6232334448672797, gamma=0.4330880728874676, learning_rate=0.19033450352296263, max_depth=5, min_child_weight=6, n_estimators=408, scale_pos_weight=1, subsample=0.8887995089067299; total time=   0.5s
# [CV] END colsample_bytree=0.9754210836063001, gamma=0.00038938292050716417, learning_rate=0.30766346778736525, max_depth=3, min_child_weight=6, n_estimators=352, scale_pos_weight=1, subsample=0.6092249700165663; total time=   0.4s
# [CV] END colsample_bytree=0.9754210836063001, gamma=0.00038938292050716417, learning_rate=0.30766346778736525, max_depth=3, min_child_weight=6, n_estimators=352, scale_pos_weight=1, subsample=0.6092249700165663; total time=   0.5s
# [CV] END colsample_bytree=0.9754210836063001, gamma=0.00038938292050716417, learning_rate=0.30766346778736525, max_depth=3, min_child_weight=6, n_estimators=352, scale_pos_weight=1, subsample=0.6092249700165663; total time=   0.4s
# [CV] END colsample_bytree=0.8099098641033556, gamma=0.19993048585762774, learning_rate=0.023999698964084628, max_depth=6, min_child_weight=3, n_estimators=975, scale_pos_weight=2.0, subsample=0.9932923543227152; total time=   2.2s
# [CV] END colsample_bytree=0.8099098641033556, gamma=0.19993048585762774, learning_rate=0.023999698964084628, max_depth=6, min_child_weight=3, n_estimators=975, scale_pos_weight=2.0, subsample=0.9932923543227152; total time=   2.7s
# [CV] END colsample_bytree=0.786705157299192, gamma=0.4299702033681603, learning_rate=0.2140922615763339, max_depth=3, min_child_weight=7, n_estimators=373, scale_pos_weight=1, subsample=0.9768807022739411; total time=   0.3s
# [CV] END colsample_bytree=0.786705157299192, gamma=0.4299702033681603, learning_rate=0.2140922615763339, max_depth=3, min_child_weight=7, n_estimators=373, scale_pos_weight=1, subsample=0.9768807022739411; total time=   0.4s
# [CV] END colsample_bytree=0.786705157299192, gamma=0.4299702033681603, learning_rate=0.2140922615763339, max_depth=3, min_child_weight=7, n_estimators=373, scale_pos_weight=1, subsample=0.9768807022739411; total time=   0.4s
# [CV] END colsample_bytree=0.786705157299192, gamma=0.4299702033681603, learning_rate=0.2140922615763339, max_depth=3, min_child_weight=7, n_estimators=373, scale_pos_weight=1, subsample=0.9768807022739411; total time=   0.3s
# [CV] END colsample_bytree=0.786705157299192, gamma=0.4299702033681603, learning_rate=0.2140922615763339, max_depth=3, min_child_weight=7, n_estimators=373, scale_pos_weight=1, subsample=0.9768807022739411; total time=   0.3s
# [CV] END colsample_bytree=0.8253152871382157, gamma=0.19270825126995805, learning_rate=0.014789875666064259, max_depth=4, min_child_weight=4, n_estimators=191, scale_pos_weight=2.0, subsample=0.8733054075301833; total time=   0.4s
# [CV] END colsample_bytree=0.8253152871382157, gamma=0.19270825126995805, learning_rate=0.014789875666064259, max_depth=4, min_child_weight=4, n_estimators=191, scale_pos_weight=2.0, subsample=0.8733054075301833; total time=   0.3s
# [CV] END colsample_bytree=0.8439986631130484, gamma=0.41659745586808217, learning_rate=0.062009396052331626, max_depth=3, min_child_weight=4, n_estimators=661, scale_pos_weight=1, subsample=0.902144564127061; total time=   0.7s
# [CV] END colsample_bytree=0.8439986631130484, gamma=0.41659745586808217, learning_rate=0.062009396052331626, max_depth=3, min_child_weight=4, n_estimators=661, scale_pos_weight=1, subsample=0.902144564127061; total time=   0.7s
# [CV] END colsample_bytree=0.7700623497964979, gamma=0.10397083143409441, learning_rate=0.18031009834599745, max_depth=7, min_child_weight=2, n_estimators=829, scale_pos_weight=1, subsample=0.9757995766256756; total time=   0.9s
# [CV] END colsample_bytree=0.7700623497964979, gamma=0.10397083143409441, learning_rate=0.18031009834599745, max_depth=7, min_child_weight=2, n_estimators=829, scale_pos_weight=1, subsample=0.9757995766256756; total time=   0.8s
# [CV] END colsample_bytree=0.7700623497964979, gamma=0.10397083143409441, learning_rate=0.18031009834599745, max_depth=7, min_child_weight=2, n_estimators=829, scale_pos_weight=1, subsample=0.9757995766256756; total time=   0.7s
# [CV] END colsample_bytree=0.9579309401710595, gamma=0.29894998940554257, learning_rate=0.28656227050693506, max_depth=8, min_child_weight=7, n_estimators=351, scale_pos_weight=2.0, subsample=0.9844688097397396; total time=   0.3s
# [CV] END colsample_bytree=0.9579309401710595, gamma=0.29894998940554257, learning_rate=0.28656227050693506, max_depth=8, min_child_weight=7, n_estimators=351, scale_pos_weight=2.0, subsample=0.9844688097397396; total time=   0.3s
# [CV] END colsample_bytree=0.9579309401710595, gamma=0.29894998940554257, learning_rate=0.28656227050693506, max_depth=8, min_child_weight=7, n_estimators=351, scale_pos_weight=2.0, subsample=0.9844688097397396; total time=   0.4s
# [CV] END colsample_bytree=0.9378135394712606, gamma=0.37366005506869043, learning_rate=0.17190763971672393, max_depth=4, min_child_weight=9, n_estimators=863, scale_pos_weight=1, subsample=0.8170784332632994; total time=   0.8s
# [CV] END colsample_bytree=0.9378135394712606, gamma=0.37366005506869043, learning_rate=0.17190763971672393, max_depth=4, min_child_weight=9, n_estimators=863, scale_pos_weight=1, subsample=0.8170784332632994; total time=   0.9s
# [CV] END colsample_bytree=0.9378135394712606, gamma=0.37366005506869043, learning_rate=0.17190763971672393, max_depth=4, min_child_weight=9, n_estimators=863, scale_pos_weight=1, subsample=0.8170784332632994; total time=   1.1s
# [CV] END colsample_bytree=0.6563696899899051, gamma=0.40109849037701983, learning_rate=0.032365193103931246, max_depth=9, min_child_weight=9, n_estimators=443, scale_pos_weight=2.0, subsample=0.679486272613669; total time=   0.7s
# [CV] END colsample_bytree=0.6563696899899051, gamma=0.40109849037701983, learning_rate=0.032365193103931246, max_depth=9, min_child_weight=9, n_estimators=443, scale_pos_weight=2.0, subsample=0.679486272613669; total time=   0.9s
# [CV] END colsample_bytree=0.602208846849441, gamma=0.4077307142274171, learning_rate=0.22205720315428515, max_depth=5, min_child_weight=3, n_estimators=388, scale_pos_weight=2.0, subsample=0.6296178606936361; total time=   0.5s
# [CV] END colsample_bytree=0.602208846849441, gamma=0.4077307142274171, learning_rate=0.22205720315428515, max_depth=5, min_child_weight=3, n_estimators=388, scale_pos_weight=2.0, subsample=0.6296178606936361; total time=   0.6s
# [CV] END colsample_bytree=0.602208846849441, gamma=0.4077307142274171, learning_rate=0.22205720315428515, max_depth=5, min_child_weight=3, n_estimators=388, scale_pos_weight=2.0, subsample=0.6296178606936361; total time=   0.5s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.05793452976256486, learning_rate=0.2689310277626781, max_depth=6, min_child_weight=2, n_estimators=132, scale_pos_weight=1, subsample=0.7483273008793065; total time=   0.3s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.05793452976256486, learning_rate=0.2689310277626781, max_depth=6, min_child_weight=2, n_estimators=132, scale_pos_weight=1, subsample=0.7483273008793065; total time=   0.4s
# [CV] END colsample_bytree=0.8675365010654429, gamma=0.33296117830874833, learning_rate=0.18738933631231813, max_depth=8, min_child_weight=3, n_estimators=838, scale_pos_weight=2.0, subsample=0.9886848381556415; total time=   0.7s
# [CV] END colsample_bytree=0.749816047538945, gamma=0.4753571532049581, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=5, n_estimators=714, scale_pos_weight=1, subsample=0.662397808134481; total time=   0.6s
# [CV] END colsample_bytree=0.749816047538945, gamma=0.4753571532049581, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=5, n_estimators=714, scale_pos_weight=1, subsample=0.662397808134481; total time=   0.6s
# [CV] END colsample_bytree=0.749816047538945, gamma=0.4753571532049581, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=5, n_estimators=714, scale_pos_weight=1, subsample=0.662397808134481; total time=   0.6s
# [CV] END colsample_bytree=0.6232334448672797, gamma=0.4330880728874676, learning_rate=0.19033450352296263, max_depth=5, min_child_weight=6, n_estimators=408, scale_pos_weight=1, subsample=0.8887995089067299; total time=   0.5s
# [CV] END colsample_bytree=0.6232334448672797, gamma=0.4330880728874676, learning_rate=0.19033450352296263, max_depth=5, min_child_weight=6, n_estimators=408, scale_pos_weight=1, subsample=0.8887995089067299; total time=   0.5s
# [CV] END colsample_bytree=0.6232334448672797, gamma=0.4330880728874676, learning_rate=0.19033450352296263, max_depth=5, min_child_weight=6, n_estimators=408, scale_pos_weight=1, subsample=0.8887995089067299; total time=   0.4s
# [CV] END colsample_bytree=0.9754210836063001, gamma=0.00038938292050716417, learning_rate=0.30766346778736525, max_depth=3, min_child_weight=6, n_estimators=352, scale_pos_weight=1, subsample=0.6092249700165663; total time=   0.5s
# [CV] END colsample_bytree=0.9754210836063001, gamma=0.00038938292050716417, learning_rate=0.30766346778736525, max_depth=3, min_child_weight=6, n_estimators=352, scale_pos_weight=1, subsample=0.6092249700165663; total time=   0.5s
# [CV] END colsample_bytree=0.8099098641033556, gamma=0.19993048585762774, learning_rate=0.023999698964084628, max_depth=6, min_child_weight=3, n_estimators=975, scale_pos_weight=2.0, subsample=0.9932923543227152; total time=   1.7s
# [CV] END colsample_bytree=0.8099098641033556, gamma=0.19993048585762774, learning_rate=0.023999698964084628, max_depth=6, min_child_weight=3, n_estimators=975, scale_pos_weight=2.0, subsample=0.9932923543227152; total time=   2.3s
# [CV] END colsample_bytree=0.8099098641033556, gamma=0.19993048585762774, learning_rate=0.023999698964084628, max_depth=6, min_child_weight=3, n_estimators=975, scale_pos_weight=2.0, subsample=0.9932923543227152; total time=   2.4s
# [CV] END colsample_bytree=0.8253152871382157, gamma=0.19270825126995805, learning_rate=0.014789875666064259, max_depth=4, min_child_weight=4, n_estimators=191, scale_pos_weight=2.0, subsample=0.8733054075301833; total time=   0.3s
# [CV] END colsample_bytree=0.8253152871382157, gamma=0.19270825126995805, learning_rate=0.014789875666064259, max_depth=4, min_child_weight=4, n_estimators=191, scale_pos_weight=2.0, subsample=0.8733054075301833; total time=   0.4s
# [CV] END colsample_bytree=0.8253152871382157, gamma=0.19270825126995805, learning_rate=0.014789875666064259, max_depth=4, min_child_weight=4, n_estimators=191, scale_pos_weight=2.0, subsample=0.8733054075301833; total time=   0.3s
# [CV] END colsample_bytree=0.8439986631130484, gamma=0.41659745586808217, learning_rate=0.062009396052331626, max_depth=3, min_child_weight=4, n_estimators=661, scale_pos_weight=1, subsample=0.902144564127061; total time=   0.7s
# [CV] END colsample_bytree=0.8439986631130484, gamma=0.41659745586808217, learning_rate=0.062009396052331626, max_depth=3, min_child_weight=4, n_estimators=661, scale_pos_weight=1, subsample=0.902144564127061; total time=   0.7s
# [CV] END colsample_bytree=0.8439986631130484, gamma=0.41659745586808217, learning_rate=0.062009396052331626, max_depth=3, min_child_weight=4, n_estimators=661, scale_pos_weight=1, subsample=0.902144564127061; total time=   0.7s
# [CV] END colsample_bytree=0.7700623497964979, gamma=0.10397083143409441, learning_rate=0.18031009834599745, max_depth=7, min_child_weight=2, n_estimators=829, scale_pos_weight=1, subsample=0.9757995766256756; total time=   1.0s
# [CV] END colsample_bytree=0.7700623497964979, gamma=0.10397083143409441, learning_rate=0.18031009834599745, max_depth=7, min_child_weight=2, n_estimators=829, scale_pos_weight=1, subsample=0.9757995766256756; total time=   0.9s
# [CV] END colsample_bytree=0.9579309401710595, gamma=0.29894998940554257, learning_rate=0.28656227050693506, max_depth=8, min_child_weight=7, n_estimators=351, scale_pos_weight=2.0, subsample=0.9844688097397396; total time=   0.5s
# [CV] END colsample_bytree=0.9579309401710595, gamma=0.29894998940554257, learning_rate=0.28656227050693506, max_depth=8, min_child_weight=7, n_estimators=351, scale_pos_weight=2.0, subsample=0.9844688097397396; total time=   0.4s
# [CV] END colsample_bytree=0.9378135394712606, gamma=0.37366005506869043, learning_rate=0.17190763971672393, max_depth=4, min_child_weight=9, n_estimators=863, scale_pos_weight=1, subsample=0.8170784332632994; total time=   1.0s
# [CV] END colsample_bytree=0.9378135394712606, gamma=0.37366005506869043, learning_rate=0.17190763971672393, max_depth=4, min_child_weight=9, n_estimators=863, scale_pos_weight=1, subsample=0.8170784332632994; total time=   0.9s
# [CV] END colsample_bytree=0.6563696899899051, gamma=0.40109849037701983, learning_rate=0.032365193103931246, max_depth=9, min_child_weight=9, n_estimators=443, scale_pos_weight=2.0, subsample=0.679486272613669; total time=   1.0s
# [CV] END colsample_bytree=0.6563696899899051, gamma=0.40109849037701983, learning_rate=0.032365193103931246, max_depth=9, min_child_weight=9, n_estimators=443, scale_pos_weight=2.0, subsample=0.679486272613669; total time=   0.9s
# [CV] END colsample_bytree=0.6563696899899051, gamma=0.40109849037701983, learning_rate=0.032365193103931246, max_depth=9, min_child_weight=9, n_estimators=443, scale_pos_weight=2.0, subsample=0.679486272613669; total time=   0.7s
# [CV] END colsample_bytree=0.602208846849441, gamma=0.4077307142274171, learning_rate=0.22205720315428515, max_depth=5, min_child_weight=3, n_estimators=388, scale_pos_weight=2.0, subsample=0.6296178606936361; total time=   0.5s
# [CV] END colsample_bytree=0.602208846849441, gamma=0.4077307142274171, learning_rate=0.22205720315428515, max_depth=5, min_child_weight=3, n_estimators=388, scale_pos_weight=2.0, subsample=0.6296178606936361; total time=   0.5s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.05793452976256486, learning_rate=0.2689310277626781, max_depth=6, min_child_weight=2, n_estimators=132, scale_pos_weight=1, subsample=0.7483273008793065; total time=   0.2s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.05793452976256486, learning_rate=0.2689310277626781, max_depth=6, min_child_weight=2, n_estimators=132, scale_pos_weight=1, subsample=0.7483273008793065; total time=   0.4s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.05793452976256486, learning_rate=0.2689310277626781, max_depth=6, min_child_weight=2, n_estimators=132, scale_pos_weight=1, subsample=0.7483273008793065; total time=   0.4s
# [CV] END colsample_bytree=0.8675365010654429, gamma=0.33296117830874833, learning_rate=0.18738933631231813, max_depth=8, min_child_weight=3, n_estimators=838, scale_pos_weight=2.0, subsample=0.9886848381556415; total time=   0.7s
# [CV] END colsample_bytree=0.8675365010654429, gamma=0.33296117830874833, learning_rate=0.18738933631231813, max_depth=8, min_child_weight=3, n_estimators=838, scale_pos_weight=2.0, subsample=0.9886848381556415; total time=   0.7s
# [CV] END colsample_bytree=0.8675365010654429, gamma=0.33296117830874833, learning_rate=0.18738933631231813, max_depth=8, min_child_weight=3, n_estimators=838, scale_pos_weight=2.0, subsample=0.9886848381556415; total time=   0.7s
# [CV] END colsample_bytree=0.9395655297064336, gamma=0.3608647605824366, learning_rate=0.08079547592468672, max_depth=8, min_child_weight=7, n_estimators=894, scale_pos_weight=2.0, subsample=0.8842651558743149; total time=   1.2s
# [CV] END colsample_bytree=0.8675365010654429, gamma=0.33296117830874833, learning_rate=0.18738933631231813, max_depth=8, min_child_weight=3, n_estimators=838, scale_pos_weight=2.0, subsample=0.9886848381556415; total time=   0.8s
# [CV] END colsample_bytree=0.9395655297064336, gamma=0.3608647605824366, learning_rate=0.08079547592468672, max_depth=8, min_child_weight=7, n_estimators=894, scale_pos_weight=2.0, subsample=0.8842651558743149; total time=   1.2s
# [CV] END colsample_bytree=0.9395655297064336, gamma=0.3608647605824366, learning_rate=0.08079547592468672, max_depth=8, min_child_weight=7, n_estimators=894, scale_pos_weight=2.0, subsample=0.8842651558743149; total time=   1.1s
# [CV] END colsample_bytree=0.9395655297064336, gamma=0.3608647605824366, learning_rate=0.08079547592468672, max_depth=8, min_child_weight=7, n_estimators=894, scale_pos_weight=2.0, subsample=0.8842651558743149; total time=   1.1s
# [CV] END colsample_bytree=0.6443563283247326, gamma=0.21966825093288506, learning_rate=0.07051576070061885, max_depth=9, min_child_weight=1, n_estimators=663, scale_pos_weight=2.0, subsample=0.8034282764658811; total time=   1.1s
# [CV] END colsample_bytree=0.6443563283247326, gamma=0.21966825093288506, learning_rate=0.07051576070061885, max_depth=9, min_child_weight=1, n_estimators=663, scale_pos_weight=2.0, subsample=0.8034282764658811; total time=   1.1s
# [CV] END colsample_bytree=0.9630265895704372, gamma=0.12464611457443747, learning_rate=0.1331148769106889, max_depth=5, min_child_weight=4, n_estimators=624, scale_pos_weight=1, subsample=0.8395461865954144; total time=   0.9s
# [CV] END colsample_bytree=0.9630265895704372, gamma=0.12464611457443747, learning_rate=0.1331148769106889, max_depth=5, min_child_weight=4, n_estimators=624, scale_pos_weight=1, subsample=0.8395461865954144; total time=   1.0s
# [CV] END colsample_bytree=0.9630265895704372, gamma=0.12464611457443747, learning_rate=0.1331148769106889, max_depth=5, min_child_weight=4, n_estimators=624, scale_pos_weight=1, subsample=0.8395461865954144; total time=   0.9s
# [CV] END colsample_bytree=0.8779139732158818, gamma=0.44023391950762886, learning_rate=0.197306214440138, max_depth=8, min_child_weight=9, n_estimators=745, scale_pos_weight=1, subsample=0.9214688307596458; total time=   0.7s
# [CV] END colsample_bytree=0.8779139732158818, gamma=0.44023391950762886, learning_rate=0.197306214440138, max_depth=8, min_child_weight=9, n_estimators=745, scale_pos_weight=1, subsample=0.9214688307596458; total time=   0.7s
# [CV] END colsample_bytree=0.6746280235544143, gamma=0.4462794992449889, learning_rate=0.17180267257469523, max_depth=4, min_child_weight=7, n_estimators=447, scale_pos_weight=2.0, subsample=0.7272013899887455; total time=   0.5s
# [CV] END colsample_bytree=0.6746280235544143, gamma=0.4462794992449889, learning_rate=0.17180267257469523, max_depth=4, min_child_weight=7, n_estimators=447, scale_pos_weight=2.0, subsample=0.7272013899887455; total time=   0.5s
# [CV] END colsample_bytree=0.6440207698110707, gamma=0.11396758127097084, learning_rate=0.1381323365878769, max_depth=6, min_child_weight=9, n_estimators=358, scale_pos_weight=2.0, subsample=0.6658623412571767; total time=   0.5s
# [CV] END colsample_bytree=0.6440207698110707, gamma=0.11396758127097084, learning_rate=0.1381323365878769, max_depth=6, min_child_weight=9, n_estimators=358, scale_pos_weight=2.0, subsample=0.6658623412571767; total time=   0.5s
# [CV] END colsample_bytree=0.6440207698110707, gamma=0.11396758127097084, learning_rate=0.1381323365878769, max_depth=6, min_child_weight=9, n_estimators=358, scale_pos_weight=2.0, subsample=0.6658623412571767; total time=   0.5s
# [CV] END colsample_bytree=0.8136357677501768, gamma=0.2424149856794916, learning_rate=0.2177308098670811, max_depth=4, min_child_weight=8, n_estimators=926, scale_pos_weight=1, subsample=0.687505687829228; total time=   0.8s
# [CV] END colsample_bytree=0.8136357677501768, gamma=0.2424149856794916, learning_rate=0.2177308098670811, max_depth=4, min_child_weight=8, n_estimators=926, scale_pos_weight=1, subsample=0.687505687829228; total time=   0.9s
# [CV] END colsample_bytree=0.8232408008069365, gamma=0.2019180855290204, learning_rate=0.029467674132694466, max_depth=4, min_child_weight=4, n_estimators=367, scale_pos_weight=1, subsample=0.8785217091359153; total time=   0.5s
# [CV] END colsample_bytree=0.8232408008069365, gamma=0.2019180855290204, learning_rate=0.029467674132694466, max_depth=4, min_child_weight=4, n_estimators=367, scale_pos_weight=1, subsample=0.8785217091359153; total time=   0.5s
# [CV] END colsample_bytree=0.8232408008069365, gamma=0.2019180855290204, learning_rate=0.029467674132694466, max_depth=4, min_child_weight=4, n_estimators=367, scale_pos_weight=1, subsample=0.8785217091359153; total time=   0.6s
# [CV] END colsample_bytree=0.8849082359697769, gamma=0.07404346497669995, learning_rate=0.30932214551468257, max_depth=5, min_child_weight=1, n_estimators=101, scale_pos_weight=1, subsample=0.7644148053272926; total time=   0.4s
# [CV] END colsample_bytree=0.8849082359697769, gamma=0.07404346497669995, learning_rate=0.30932214551468257, max_depth=5, min_child_weight=1, n_estimators=101, scale_pos_weight=1, subsample=0.7644148053272926; total time=   0.4s
# [CV] END colsample_bytree=0.6132202931602193, gamma=0.1725356240133415, learning_rate=0.20030540341040914, max_depth=8, min_child_weight=2, n_estimators=152, scale_pos_weight=1, subsample=0.7791132658292367; total time=   0.5s
# [CV] END colsample_bytree=0.6132202931602193, gamma=0.1725356240133415, learning_rate=0.20030540341040914, max_depth=8, min_child_weight=2, n_estimators=152, scale_pos_weight=1, subsample=0.7791132658292367; total time=   0.5s
# [CV] END colsample_bytree=0.8211572356285312, gamma=0.29634836193969677, learning_rate=0.03425599789981457, max_depth=5, min_child_weight=1, n_estimators=866, scale_pos_weight=1, subsample=0.7471132530877013; total time=   2.3s
# [CV] END colsample_bytree=0.8211572356285312, gamma=0.29634836193969677, learning_rate=0.03425599789981457, max_depth=5, min_child_weight=1, n_estimators=866, scale_pos_weight=1, subsample=0.7471132530877013; total time=   2.2s
# [CV] END colsample_bytree=0.8529223322374317, gamma=0.31676485538044735, learning_rate=0.17073240522242755, max_depth=3, min_child_weight=9, n_estimators=223, scale_pos_weight=2.0, subsample=0.6746074041599417; total time=   0.2s
# [CV] END colsample_bytree=0.8529223322374317, gamma=0.31676485538044735, learning_rate=0.17073240522242755, max_depth=3, min_child_weight=9, n_estimators=223, scale_pos_weight=2.0, subsample=0.6746074041599417; total time=   0.3s
# [CV] END colsample_bytree=0.8529223322374317, gamma=0.31676485538044735, learning_rate=0.17073240522242755, max_depth=3, min_child_weight=9, n_estimators=223, scale_pos_weight=2.0, subsample=0.6746074041599417; total time=   0.3s
# [CV] END colsample_bytree=0.8529223322374317, gamma=0.31676485538044735, learning_rate=0.17073240522242755, max_depth=3, min_child_weight=9, n_estimators=223, scale_pos_weight=2.0, subsample=0.6746074041599417; total time=   0.2s
# [CV] END colsample_bytree=0.6163100566219055, gamma=0.2954464715941209, learning_rate=0.21326930855268472, max_depth=5, min_child_weight=3, n_estimators=610, scale_pos_weight=2.0, subsample=0.7394663949166917; total time=   0.6s
# [CV] END colsample_bytree=0.6163100566219055, gamma=0.2954464715941209, learning_rate=0.21326930855268472, max_depth=5, min_child_weight=3, n_estimators=610, scale_pos_weight=2.0, subsample=0.7394663949166917; total time=   0.6s
# [CV] END colsample_bytree=0.6384706204365683, gamma=0.470261632244802, learning_rate=0.1292716063262567, max_depth=9, min_child_weight=2, n_estimators=971, scale_pos_weight=2.0, subsample=0.8702760468157122; total time=   0.7s
# [CV] END colsample_bytree=0.6384706204365683, gamma=0.470261632244802, learning_rate=0.1292716063262567, max_depth=9, min_child_weight=2, n_estimators=971, scale_pos_weight=2.0, subsample=0.8702760468157122; total time=   0.8s
# [CV] END colsample_bytree=0.9395655297064336, gamma=0.3608647605824366, learning_rate=0.08079547592468672, max_depth=8, min_child_weight=7, n_estimators=894, scale_pos_weight=2.0, subsample=0.8842651558743149; total time=   1.1s
# [CV] END colsample_bytree=0.6443563283247326, gamma=0.21966825093288506, learning_rate=0.07051576070061885, max_depth=9, min_child_weight=1, n_estimators=663, scale_pos_weight=2.0, subsample=0.8034282764658811; total time=   1.0s
# [CV] END colsample_bytree=0.6443563283247326, gamma=0.21966825093288506, learning_rate=0.07051576070061885, max_depth=9, min_child_weight=1, n_estimators=663, scale_pos_weight=2.0, subsample=0.8034282764658811; total time=   1.1s
# [CV] END colsample_bytree=0.6443563283247326, gamma=0.21966825093288506, learning_rate=0.07051576070061885, max_depth=9, min_child_weight=1, n_estimators=663, scale_pos_weight=2.0, subsample=0.8034282764658811; total time=   1.0s
# [CV] END colsample_bytree=0.9630265895704372, gamma=0.12464611457443747, learning_rate=0.1331148769106889, max_depth=5, min_child_weight=4, n_estimators=624, scale_pos_weight=1, subsample=0.8395461865954144; total time=   0.9s
# [CV] END colsample_bytree=0.9630265895704372, gamma=0.12464611457443747, learning_rate=0.1331148769106889, max_depth=5, min_child_weight=4, n_estimators=624, scale_pos_weight=1, subsample=0.8395461865954144; total time=   0.9s
# [CV] END colsample_bytree=0.8779139732158818, gamma=0.44023391950762886, learning_rate=0.197306214440138, max_depth=8, min_child_weight=9, n_estimators=745, scale_pos_weight=1, subsample=0.9214688307596458; total time=   0.6s
# [CV] END colsample_bytree=0.8779139732158818, gamma=0.44023391950762886, learning_rate=0.197306214440138, max_depth=8, min_child_weight=9, n_estimators=745, scale_pos_weight=1, subsample=0.9214688307596458; total time=   0.6s
# [CV] END colsample_bytree=0.8779139732158818, gamma=0.44023391950762886, learning_rate=0.197306214440138, max_depth=8, min_child_weight=9, n_estimators=745, scale_pos_weight=1, subsample=0.9214688307596458; total time=   0.7s
# [CV] END colsample_bytree=0.6746280235544143, gamma=0.4462794992449889, learning_rate=0.17180267257469523, max_depth=4, min_child_weight=7, n_estimators=447, scale_pos_weight=2.0, subsample=0.7272013899887455; total time=   0.5s
# [CV] END colsample_bytree=0.6746280235544143, gamma=0.4462794992449889, learning_rate=0.17180267257469523, max_depth=4, min_child_weight=7, n_estimators=447, scale_pos_weight=2.0, subsample=0.7272013899887455; total time=   0.5s
# [CV] END colsample_bytree=0.6746280235544143, gamma=0.4462794992449889, learning_rate=0.17180267257469523, max_depth=4, min_child_weight=7, n_estimators=447, scale_pos_weight=2.0, subsample=0.7272013899887455; total time=   0.5s
# [CV] END colsample_bytree=0.6440207698110707, gamma=0.11396758127097084, learning_rate=0.1381323365878769, max_depth=6, min_child_weight=9, n_estimators=358, scale_pos_weight=2.0, subsample=0.6658623412571767; total time=   0.5s
# [CV] END colsample_bytree=0.6440207698110707, gamma=0.11396758127097084, learning_rate=0.1381323365878769, max_depth=6, min_child_weight=9, n_estimators=358, scale_pos_weight=2.0, subsample=0.6658623412571767; total time=   0.5s
# [CV] END colsample_bytree=0.8136357677501768, gamma=0.2424149856794916, learning_rate=0.2177308098670811, max_depth=4, min_child_weight=8, n_estimators=926, scale_pos_weight=1, subsample=0.687505687829228; total time=   0.9s
# [CV] END colsample_bytree=0.8136357677501768, gamma=0.2424149856794916, learning_rate=0.2177308098670811, max_depth=4, min_child_weight=8, n_estimators=926, scale_pos_weight=1, subsample=0.687505687829228; total time=   0.9s
# [CV] END colsample_bytree=0.8136357677501768, gamma=0.2424149856794916, learning_rate=0.2177308098670811, max_depth=4, min_child_weight=8, n_estimators=926, scale_pos_weight=1, subsample=0.687505687829228; total time=   0.9s
# [CV] END colsample_bytree=0.8232408008069365, gamma=0.2019180855290204, learning_rate=0.029467674132694466, max_depth=4, min_child_weight=4, n_estimators=367, scale_pos_weight=1, subsample=0.8785217091359153; total time=   0.5s
# [CV] END colsample_bytree=0.8232408008069365, gamma=0.2019180855290204, learning_rate=0.029467674132694466, max_depth=4, min_child_weight=4, n_estimators=367, scale_pos_weight=1, subsample=0.8785217091359153; total time=   0.5s
# [CV] END colsample_bytree=0.8849082359697769, gamma=0.07404346497669995, learning_rate=0.30932214551468257, max_depth=5, min_child_weight=1, n_estimators=101, scale_pos_weight=1, subsample=0.7644148053272926; total time=   0.3s
# [CV] END colsample_bytree=0.8849082359697769, gamma=0.07404346497669995, learning_rate=0.30932214551468257, max_depth=5, min_child_weight=1, n_estimators=101, scale_pos_weight=1, subsample=0.7644148053272926; total time=   0.2s
# [CV] END colsample_bytree=0.8849082359697769, gamma=0.07404346497669995, learning_rate=0.30932214551468257, max_depth=5, min_child_weight=1, n_estimators=101, scale_pos_weight=1, subsample=0.7644148053272926; total time=   0.2s
# [CV] END colsample_bytree=0.6132202931602193, gamma=0.1725356240133415, learning_rate=0.20030540341040914, max_depth=8, min_child_weight=2, n_estimators=152, scale_pos_weight=1, subsample=0.7791132658292367; total time=   0.4s
# [CV] END colsample_bytree=0.6132202931602193, gamma=0.1725356240133415, learning_rate=0.20030540341040914, max_depth=8, min_child_weight=2, n_estimators=152, scale_pos_weight=1, subsample=0.7791132658292367; total time=   0.3s
# [CV] END colsample_bytree=0.6132202931602193, gamma=0.1725356240133415, learning_rate=0.20030540341040914, max_depth=8, min_child_weight=2, n_estimators=152, scale_pos_weight=1, subsample=0.7791132658292367; total time=   0.3s
# [CV] END colsample_bytree=0.8211572356285312, gamma=0.29634836193969677, learning_rate=0.03425599789981457, max_depth=5, min_child_weight=1, n_estimators=866, scale_pos_weight=1, subsample=0.7471132530877013; total time=   1.5s
# [CV] END colsample_bytree=0.8211572356285312, gamma=0.29634836193969677, learning_rate=0.03425599789981457, max_depth=5, min_child_weight=1, n_estimators=866, scale_pos_weight=1, subsample=0.7471132530877013; total time=   1.6s
# [CV] END colsample_bytree=0.8211572356285312, gamma=0.29634836193969677, learning_rate=0.03425599789981457, max_depth=5, min_child_weight=1, n_estimators=866, scale_pos_weight=1, subsample=0.7471132530877013; total time=   1.7s
# [CV] END colsample_bytree=0.8529223322374317, gamma=0.31676485538044735, learning_rate=0.17073240522242755, max_depth=3, min_child_weight=9, n_estimators=223, scale_pos_weight=2.0, subsample=0.6746074041599417; total time=   0.3s
# [CV] END colsample_bytree=0.6163100566219055, gamma=0.2954464715941209, learning_rate=0.21326930855268472, max_depth=5, min_child_weight=3, n_estimators=610, scale_pos_weight=2.0, subsample=0.7394663949166917; total time=   0.6s
# [CV] END colsample_bytree=0.6163100566219055, gamma=0.2954464715941209, learning_rate=0.21326930855268472, max_depth=5, min_child_weight=3, n_estimators=610, scale_pos_weight=2.0, subsample=0.7394663949166917; total time=   0.6s
# [CV] END colsample_bytree=0.6163100566219055, gamma=0.2954464715941209, learning_rate=0.21326930855268472, max_depth=5, min_child_weight=3, n_estimators=610, scale_pos_weight=2.0, subsample=0.7394663949166917; total time=   0.5s
# [CV] END colsample_bytree=0.6384706204365683, gamma=0.470261632244802, learning_rate=0.1292716063262567, max_depth=9, min_child_weight=2, n_estimators=971, scale_pos_weight=2.0, subsample=0.8702760468157122; total time=   0.7s
# [CV] END colsample_bytree=0.6384706204365683, gamma=0.470261632244802, learning_rate=0.1292716063262567, max_depth=9, min_child_weight=2, n_estimators=971, scale_pos_weight=2.0, subsample=0.8702760468157122; total time=   0.8s
# [CV] END colsample_bytree=0.8940864476963089, gamma=0.10453581036885684, learning_rate=0.17243439214826975, max_depth=4, min_child_weight=3, n_estimators=362, scale_pos_weight=1, subsample=0.6699819708383744; total time=   0.5s
# [CV] END colsample_bytree=0.8940864476963089, gamma=0.10453581036885684, learning_rate=0.17243439214826975, max_depth=4, min_child_weight=3, n_estimators=362, scale_pos_weight=1, subsample=0.6699819708383744; total time=   0.6s
# [CV] END colsample_bytree=0.8940864476963089, gamma=0.10453581036885684, learning_rate=0.17243439214826975, max_depth=4, min_child_weight=3, n_estimators=362, scale_pos_weight=1, subsample=0.6699819708383744; total time=   0.5s
# [CV] END colsample_bytree=0.9928673373317742, gamma=0.25831794563550714, learning_rate=0.0882487524491227, max_depth=3, min_child_weight=5, n_estimators=136, scale_pos_weight=1, subsample=0.8532405829093072; total time=   0.2s
# [CV] END colsample_bytree=0.9928673373317742, gamma=0.25831794563550714, learning_rate=0.0882487524491227, max_depth=3, min_child_weight=5, n_estimators=136, scale_pos_weight=1, subsample=0.8532405829093072; total time=   0.2s
# [CV] END colsample_bytree=0.9928673373317742, gamma=0.25831794563550714, learning_rate=0.0882487524491227, max_depth=3, min_child_weight=5, n_estimators=136, scale_pos_weight=1, subsample=0.8532405829093072; total time=   0.2s
# [CV] END colsample_bytree=0.9928673373317742, gamma=0.25831794563550714, learning_rate=0.0882487524491227, max_depth=3, min_child_weight=5, n_estimators=136, scale_pos_weight=1, subsample=0.8532405829093072; total time=   0.2s
# [CV] END colsample_bytree=0.7356119164194803, gamma=0.17460478730633044, learning_rate=0.22778670366107182, max_depth=5, min_child_weight=4, n_estimators=251, scale_pos_weight=1, subsample=0.9119502183430496; total time=   0.3s
# [CV] END colsample_bytree=0.7356119164194803, gamma=0.17460478730633044, learning_rate=0.22778670366107182, max_depth=5, min_child_weight=4, n_estimators=251, scale_pos_weight=1, subsample=0.9119502183430496; total time=   0.4s
# [CV] END colsample_bytree=0.7356119164194803, gamma=0.17460478730633044, learning_rate=0.22778670366107182, max_depth=5, min_child_weight=4, n_estimators=251, scale_pos_weight=1, subsample=0.9119502183430496; total time=   0.4s
# [CV] END colsample_bytree=0.8568126584617151, gamma=0.042069982497524416, learning_rate=0.05848861422838413, max_depth=8, min_child_weight=8, n_estimators=951, scale_pos_weight=1, subsample=0.6036788206466518; total time=   1.3s
# [CV] END colsample_bytree=0.8568126584617151, gamma=0.042069982497524416, learning_rate=0.05848861422838413, max_depth=8, min_child_weight=8, n_estimators=951, scale_pos_weight=1, subsample=0.6036788206466518; total time=   1.2s
# [CV] END colsample_bytree=0.6405886171464128, gamma=0.3317508845540279, learning_rate=0.011518475153865606, max_depth=8, min_child_weight=2, n_estimators=805, scale_pos_weight=1, subsample=0.7793696571944989; total time=   2.4s
# [CV] END colsample_bytree=0.6405886171464128, gamma=0.3317508845540279, learning_rate=0.011518475153865606, max_depth=8, min_child_weight=2, n_estimators=805, scale_pos_weight=1, subsample=0.7793696571944989; total time=   2.1s
# [CV] END colsample_bytree=0.6405886171464128, gamma=0.3317508845540279, learning_rate=0.011518475153865606, max_depth=8, min_child_weight=2, n_estimators=805, scale_pos_weight=1, subsample=0.7793696571944989; total time=   2.2s
# [CV] END colsample_bytree=0.9977829850443283, gamma=0.08796262633867269, learning_rate=0.015422609084656261, max_depth=8, min_child_weight=5, n_estimators=915, scale_pos_weight=1, subsample=0.7465875138331439; total time=   2.0s
# [CV] END colsample_bytree=0.9977829850443283, gamma=0.08796262633867269, learning_rate=0.015422609084656261, max_depth=8, min_child_weight=5, n_estimators=915, scale_pos_weight=1, subsample=0.7465875138331439; total time=   2.0s
# [CV] END colsample_bytree=0.8976682092226249, gamma=0.36046996212606464, learning_rate=0.10241823755571676, max_depth=6, min_child_weight=3, n_estimators=569, scale_pos_weight=2.0, subsample=0.7001847274422337; total time=   1.0s
# [CV] END colsample_bytree=0.8976682092226249, gamma=0.36046996212606464, learning_rate=0.10241823755571676, max_depth=6, min_child_weight=3, n_estimators=569, scale_pos_weight=2.0, subsample=0.7001847274422337; total time=   0.9s
# [CV] END colsample_bytree=0.8976682092226249, gamma=0.36046996212606464, learning_rate=0.10241823755571676, max_depth=6, min_child_weight=3, n_estimators=569, scale_pos_weight=2.0, subsample=0.7001847274422337; total time=   0.9s
# [CV] END colsample_bytree=0.8359483390242175, gamma=0.4894464291375045, learning_rate=0.15602264588783654, max_depth=5, min_child_weight=2, n_estimators=376, scale_pos_weight=1, subsample=0.8580413448122259; total time=   0.4s
# [CV] END colsample_bytree=0.8359483390242175, gamma=0.4894464291375045, learning_rate=0.15602264588783654, max_depth=5, min_child_weight=2, n_estimators=376, scale_pos_weight=1, subsample=0.8580413448122259; total time=   0.4s
# [CV] END colsample_bytree=0.8359483390242175, gamma=0.4894464291375045, learning_rate=0.15602264588783654, max_depth=5, min_child_weight=2, n_estimators=376, scale_pos_weight=1, subsample=0.8580413448122259; total time=   0.5s
# [CV] END colsample_bytree=0.8675696238652398, gamma=0.43208378253595153, learning_rate=0.07905558047246658, max_depth=5, min_child_weight=4, n_estimators=646, scale_pos_weight=1, subsample=0.858188918362867; total time=   1.0s
# [CV] END colsample_bytree=0.8675696238652398, gamma=0.43208378253595153, learning_rate=0.07905558047246658, max_depth=5, min_child_weight=4, n_estimators=646, scale_pos_weight=1, subsample=0.858188918362867; total time=   1.0s
# [CV] END colsample_bytree=0.6708442717628196, gamma=0.47022929217645715, learning_rate=0.2961785731007762, max_depth=7, min_child_weight=6, n_estimators=198, scale_pos_weight=1, subsample=0.606182646611547; total time=   0.3s
# [CV] END colsample_bytree=0.6708442717628196, gamma=0.47022929217645715, learning_rate=0.2961785731007762, max_depth=7, min_child_weight=6, n_estimators=198, scale_pos_weight=1, subsample=0.606182646611547; total time=   0.3s
# [CV] END colsample_bytree=0.6708442717628196, gamma=0.47022929217645715, learning_rate=0.2961785731007762, max_depth=7, min_child_weight=6, n_estimators=198, scale_pos_weight=1, subsample=0.606182646611547; total time=   0.3s
# [CV] END colsample_bytree=0.9713274250350902, gamma=0.21409207415865716, learning_rate=0.29999644571310086, max_depth=5, min_child_weight=1, n_estimators=215, scale_pos_weight=2.0, subsample=0.7222788077148727; total time=   0.3s
# [CV] END colsample_bytree=0.9713274250350902, gamma=0.21409207415865716, learning_rate=0.29999644571310086, max_depth=5, min_child_weight=1, n_estimators=215, scale_pos_weight=2.0, subsample=0.7222788077148727; total time=   0.4s
# [CV] END colsample_bytree=0.9713274250350902, gamma=0.21409207415865716, learning_rate=0.29999644571310086, max_depth=5, min_child_weight=1, n_estimators=215, scale_pos_weight=2.0, subsample=0.7222788077148727; total time=   0.4s
# [CV] END colsample_bytree=0.6763644124601385, gamma=0.1342374284450784, learning_rate=0.1555839622828947, max_depth=4, min_child_weight=9, n_estimators=834, scale_pos_weight=1, subsample=0.8784119186699892; total time=   0.9s
# [CV] END colsample_bytree=0.6763644124601385, gamma=0.1342374284450784, learning_rate=0.1555839622828947, max_depth=4, min_child_weight=9, n_estimators=834, scale_pos_weight=1, subsample=0.8784119186699892; total time=   0.8s
# [CV] END colsample_bytree=0.6763644124601385, gamma=0.1342374284450784, learning_rate=0.1555839622828947, max_depth=4, min_child_weight=9, n_estimators=834, scale_pos_weight=1, subsample=0.8784119186699892; total time=   0.9s
# [CV] END colsample_bytree=0.828024468035746, gamma=0.04858824688538427, learning_rate=0.19450216800975093, max_depth=8, min_child_weight=7, n_estimators=738, scale_pos_weight=2.0, subsample=0.7181162353675755; total time=   0.9s
# [CV] END colsample_bytree=0.828024468035746, gamma=0.04858824688538427, learning_rate=0.19450216800975093, max_depth=8, min_child_weight=7, n_estimators=738, scale_pos_weight=2.0, subsample=0.7181162353675755; total time=   1.0s
# [CV] END colsample_bytree=0.6384706204365683, gamma=0.470261632244802, learning_rate=0.1292716063262567, max_depth=9, min_child_weight=2, n_estimators=971, scale_pos_weight=2.0, subsample=0.8702760468157122; total time=   0.8s
# [CV] END colsample_bytree=0.8940864476963089, gamma=0.10453581036885684, learning_rate=0.17243439214826975, max_depth=4, min_child_weight=3, n_estimators=362, scale_pos_weight=1, subsample=0.6699819708383744; total time=   0.9s
# [CV] END colsample_bytree=0.8940864476963089, gamma=0.10453581036885684, learning_rate=0.17243439214826975, max_depth=4, min_child_weight=3, n_estimators=362, scale_pos_weight=1, subsample=0.6699819708383744; total time=   0.8s
# [CV] END colsample_bytree=0.9928673373317742, gamma=0.25831794563550714, learning_rate=0.0882487524491227, max_depth=3, min_child_weight=5, n_estimators=136, scale_pos_weight=1, subsample=0.8532405829093072; total time=   0.3s
# [CV] END colsample_bytree=0.7356119164194803, gamma=0.17460478730633044, learning_rate=0.22778670366107182, max_depth=5, min_child_weight=4, n_estimators=251, scale_pos_weight=1, subsample=0.9119502183430496; total time=   0.5s
# [CV] END colsample_bytree=0.7356119164194803, gamma=0.17460478730633044, learning_rate=0.22778670366107182, max_depth=5, min_child_weight=4, n_estimators=251, scale_pos_weight=1, subsample=0.9119502183430496; total time=   0.3s
# [CV] END colsample_bytree=0.8568126584617151, gamma=0.042069982497524416, learning_rate=0.05848861422838413, max_depth=8, min_child_weight=8, n_estimators=951, scale_pos_weight=1, subsample=0.6036788206466518; total time=   1.3s
# [CV] END colsample_bytree=0.8568126584617151, gamma=0.042069982497524416, learning_rate=0.05848861422838413, max_depth=8, min_child_weight=8, n_estimators=951, scale_pos_weight=1, subsample=0.6036788206466518; total time=   1.5s
# [CV] END colsample_bytree=0.8568126584617151, gamma=0.042069982497524416, learning_rate=0.05848861422838413, max_depth=8, min_child_weight=8, n_estimators=951, scale_pos_weight=1, subsample=0.6036788206466518; total time=   1.3s
# [CV] END colsample_bytree=0.6405886171464128, gamma=0.3317508845540279, learning_rate=0.011518475153865606, max_depth=8, min_child_weight=2, n_estimators=805, scale_pos_weight=1, subsample=0.7793696571944989; total time=   2.0s
# [CV] END colsample_bytree=0.6405886171464128, gamma=0.3317508845540279, learning_rate=0.011518475153865606, max_depth=8, min_child_weight=2, n_estimators=805, scale_pos_weight=1, subsample=0.7793696571944989; total time=   2.1s
# [CV] END colsample_bytree=0.9977829850443283, gamma=0.08796262633867269, learning_rate=0.015422609084656261, max_depth=8, min_child_weight=5, n_estimators=915, scale_pos_weight=1, subsample=0.7465875138331439; total time=   2.3s
# [CV] END colsample_bytree=0.9977829850443283, gamma=0.08796262633867269, learning_rate=0.015422609084656261, max_depth=8, min_child_weight=5, n_estimators=915, scale_pos_weight=1, subsample=0.7465875138331439; total time=   2.2s
# [CV] END colsample_bytree=0.9977829850443283, gamma=0.08796262633867269, learning_rate=0.015422609084656261, max_depth=8, min_child_weight=5, n_estimators=915, scale_pos_weight=1, subsample=0.7465875138331439; total time=   2.0s
# [CV] END colsample_bytree=0.8976682092226249, gamma=0.36046996212606464, learning_rate=0.10241823755571676, max_depth=6, min_child_weight=3, n_estimators=569, scale_pos_weight=2.0, subsample=0.7001847274422337; total time=   0.9s
# [CV] END colsample_bytree=0.8976682092226249, gamma=0.36046996212606464, learning_rate=0.10241823755571676, max_depth=6, min_child_weight=3, n_estimators=569, scale_pos_weight=2.0, subsample=0.7001847274422337; total time=   0.8s
# [CV] END colsample_bytree=0.8359483390242175, gamma=0.4894464291375045, learning_rate=0.15602264588783654, max_depth=5, min_child_weight=2, n_estimators=376, scale_pos_weight=1, subsample=0.8580413448122259; total time=   0.4s
# [CV] END colsample_bytree=0.8359483390242175, gamma=0.4894464291375045, learning_rate=0.15602264588783654, max_depth=5, min_child_weight=2, n_estimators=376, scale_pos_weight=1, subsample=0.8580413448122259; total time=   0.4s
# [CV] END colsample_bytree=0.8675696238652398, gamma=0.43208378253595153, learning_rate=0.07905558047246658, max_depth=5, min_child_weight=4, n_estimators=646, scale_pos_weight=1, subsample=0.858188918362867; total time=   1.0s
# [CV] END colsample_bytree=0.8675696238652398, gamma=0.43208378253595153, learning_rate=0.07905558047246658, max_depth=5, min_child_weight=4, n_estimators=646, scale_pos_weight=1, subsample=0.858188918362867; total time=   0.9s
# [CV] END colsample_bytree=0.8675696238652398, gamma=0.43208378253595153, learning_rate=0.07905558047246658, max_depth=5, min_child_weight=4, n_estimators=646, scale_pos_weight=1, subsample=0.858188918362867; total time=   1.0s
# [CV] END colsample_bytree=0.6708442717628196, gamma=0.47022929217645715, learning_rate=0.2961785731007762, max_depth=7, min_child_weight=6, n_estimators=198, scale_pos_weight=1, subsample=0.606182646611547; total time=   0.3s
# [CV] END colsample_bytree=0.6708442717628196, gamma=0.47022929217645715, learning_rate=0.2961785731007762, max_depth=7, min_child_weight=6, n_estimators=198, scale_pos_weight=1, subsample=0.606182646611547; total time=   0.3s
# [CV] END colsample_bytree=0.9713274250350902, gamma=0.21409207415865716, learning_rate=0.29999644571310086, max_depth=5, min_child_weight=1, n_estimators=215, scale_pos_weight=2.0, subsample=0.7222788077148727; total time=   0.4s
# [CV] END colsample_bytree=0.9713274250350902, gamma=0.21409207415865716, learning_rate=0.29999644571310086, max_depth=5, min_child_weight=1, n_estimators=215, scale_pos_weight=2.0, subsample=0.7222788077148727; total time=   0.4s
# [CV] END colsample_bytree=0.6763644124601385, gamma=0.1342374284450784, learning_rate=0.1555839622828947, max_depth=4, min_child_weight=9, n_estimators=834, scale_pos_weight=1, subsample=0.8784119186699892; total time=   1.0s
# [CV] END colsample_bytree=0.6763644124601385, gamma=0.1342374284450784, learning_rate=0.1555839622828947, max_depth=4, min_child_weight=9, n_estimators=834, scale_pos_weight=1, subsample=0.8784119186699892; total time=   1.1s
# [CV] END colsample_bytree=0.828024468035746, gamma=0.04858824688538427, learning_rate=0.19450216800975093, max_depth=8, min_child_weight=7, n_estimators=738, scale_pos_weight=2.0, subsample=0.7181162353675755; total time=   0.9s
# [CV] END colsample_bytree=0.828024468035746, gamma=0.04858824688538427, learning_rate=0.19450216800975093, max_depth=8, min_child_weight=7, n_estimators=738, scale_pos_weight=2.0, subsample=0.7181162353675755; total time=   1.0s
# [CV] END colsample_bytree=0.828024468035746, gamma=0.04858824688538427, learning_rate=0.19450216800975093, max_depth=8, min_child_weight=7, n_estimators=738, scale_pos_weight=2.0, subsample=0.7181162353675755; total time=   0.9s
# [CV] END colsample_bytree=0.7290203056954402, gamma=0.4243348974623372, learning_rate=0.050986399432608645, max_depth=8, min_child_weight=7, n_estimators=576, scale_pos_weight=1, subsample=0.9237444621914055; total time=   0.9s
# [CV] END colsample_bytree=0.7290203056954402, gamma=0.4243348974623372, learning_rate=0.050986399432608645, max_depth=8, min_child_weight=7, n_estimators=576, scale_pos_weight=1, subsample=0.9237444621914055; total time=   0.9s
# [CV] END colsample_bytree=0.9240453578716723, gamma=0.43353615929005185, learning_rate=0.2839721657669414, max_depth=4, min_child_weight=7, n_estimators=924, scale_pos_weight=1, subsample=0.9193180715867101; total time=   0.7s
# [CV] END colsample_bytree=0.9240453578716723, gamma=0.43353615929005185, learning_rate=0.2839721657669414, max_depth=4, min_child_weight=7, n_estimators=924, scale_pos_weight=1, subsample=0.9193180715867101; total time=   0.6s
# [CV] END colsample_bytree=0.9240453578716723, gamma=0.43353615929005185, learning_rate=0.2839721657669414, max_depth=4, min_child_weight=7, n_estimators=924, scale_pos_weight=1, subsample=0.9193180715867101; total time=   0.6s
# Best parameters: {'colsample_bytree': 1.0, 'gamma': 0.1, 'learning_rate': 0.2, 'max_depth': 3, 'min_child_weight': 5, 'n_estimators': 100, 'subsample': 0.9}
# Best cross-validation score: 0.9494788985192357

# %%
# Evaluate on the test set
best_model = random_search.best_estimator_
y_pred = best_model.predict(X_test)

# %%
# evaluate the model
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1 Score: {f1}")
# Out:
# Accuracy: 0.9366786140979689
# Precision: 0.8841201716738197
# Recall: 0.8879310344827587
# F1 Score: 0.886021505376344

# %% [markdown]
# # Confusion matrix

# %%
evaluate_model(best_model, X_test, y_test)
# Out:
# Accuracy: 0.9367
# Precision: 0.8841
# Recall (Sensitivity): 0.8879
# Specificity: 0.9554
# F1 Score: 0.8860
# Balanced Accuracy: 0.9217
# ROC AUC: 0.9701
# Average Precision: 0.9213
